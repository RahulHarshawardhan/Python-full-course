# %% [markdown]
# # Exploratory Data Analysis(EDA)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\rahul\anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.2)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
iris = pd.read_csv('iris.csv')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#Once we get the data what we have to do , that is EDA. and we will do it here.
# I want to predict which type species on sepal length, sepal width, petal length, petal width.
# entire row of (sepal_length	sepal_width	petal_length	petal_width) is vector or an array in python terms.
#species is a dependent variable/ output/ class/ response/ Label
#(sepal_length	sepal_width	petal_length	petal_width) are Features/ Variable/ independent variable/ input.

# %%
#How many records and variables are there? 
print(iris.shape)
# Out:
# (150, 5)

# %%
#What all columns we have in the dataset?
print(iris.columns)
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
iris["species"].value_counts() # These types of data is called balanced data.
# Out:
# setosa        50
# virginica     50
# versicolor    50
# Name: species, dtype: int64

# %%
#What is balanced data?
# All types of species have exactly 50 datas. So these type of data is called balanced data.

#Non Balance data:
# when there is difference in datas between the categories is imbalance data.

# %% [markdown]
# # 2D Scatter Plot

# %%
iris.plot(kind = 'scatter', x = 'sepal_length', y = 'sepal_width')
plt.show()
# Out:
# C:\Users\rahul\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1041: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
# I want to give colour to it.
sns.lmplot(data = iris, x = 'sepal_length', y = 'sepal_width', fit_reg= False hue ='species')

# %%
#conclusions
#1)Using sepal length and sepal width we can distinguish setosa flower from other flower. 
# 2) verginica and versicolor separation is difficult.

# %% [markdown]
# # 3d scatter plot

# %%
# https://plotly.com/python/3d-scatter-plots/

# %%
sns.pairplot(iris, hue = 'species')

# %% [markdown]
# # Conclusion
#
# 1)petal length and petal width are the most useful features to identify vrious flower types.
#
# 2)While setosa can be very easily identified, verginica and vesicolor have some overlap.
#
# 3)We can find the linear lines and if else condition to build a simple model to clssify the flowers.

# %% [markdown]
# # Histogram

# %%
# here we are segregationg the data species wise,

iris_setosa = iris.loc[iris['species'] == 'setosa']
iris_virginica = iris.loc[iris['species'] == 'virginica']
iris_versicolor = iris.loc[iris['species'] == 'versicolor']

# %%
iris_setosa
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
iris_versicolor
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 50           7.0          3.2           4.7          1.4  versicolor
# 51           6.4          3.2           4.5          1.5  versicolor
# 52           6.9          3.1           4.9          1.5  versicolor
# 53           5.5          2.3           4.0          1.3  versicolor
# 54           6.5          2.8           4.6          1.5  versicolor
# 55           5.7          2.8           4.5          1.3  versicolor
# 56           6.3          3.3           4.7          1.6  versicolor
# 57           4.9          2.4           3.3          1.0  versicolor
# 58           6.6          2.9           4.6          1.3  versicolor
# 59           5.2          2.7           3.9          1.4  versicolor
# 60           5.0          2.0           3.5          1.0  versicolor
# 61           5.9          3.0           4.2          1.5  versicolor
# 62           6.0          2.2           4.0          1.0  versicolor
# ...

# %%
iris_virginica
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 100           6.3          3.3           6.0          2.5  virginica
# 101           5.8          2.7           5.1          1.9  virginica
# 102           7.1          3.0           5.9          2.1  virginica
# 103           6.3          2.9           5.6          1.8  virginica
# 104           6.5          3.0           5.8          2.2  virginica
# 105           7.6          3.0           6.6          2.1  virginica
# 106           4.9          2.5           4.5          1.7  virginica
# 107           7.3          2.9           6.3          1.8  virginica
# 108           6.7          2.5           5.8          1.8  virginica
# 109           7.2          3.6           6.1          2.5  virginica
# 110           6.5          3.2           5.1          2.0  virginica
# 111           6.4          2.7           5.3          1.9  virginica
# 112           6.8          3.0           5.5          2.1  virginica
# ...

# %%
# Creating 1D scatter plot
plt.plot(iris_setosa['petal_length'], np.zeros_like(iris_setosa['petal_length']), 'o')
plt.plot(iris_versicolor['petal_length'], np.zeros_like(iris_setosa['petal_length']), 'o')
plt.plot(iris_virginica['petal_length'], np.zeros_like(iris_setosa['petal_length']), 'o')
plt.show()

# %%
sns.FacetGrid(iris, hue="species", size=5) \
   .map(sns.distplot, "petal_length") \
   .add_legend();
plt.show();
# Out:
# C:\Users\rahul\anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\rahul\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\rahul\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sns.FacetGrid(iris, hue="species", size=5) \
   .map(sns.distplot, "petal_width") \
   .add_legend();
plt.show();
# Out:
# C:\Users\rahul\anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\rahul\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\rahul\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sns.FacetGrid(iris, hue="species", size=5) \
   .map(sns.distplot, "sepal_length") \
   .add_legend();
plt.show();
# Out:
# C:\Users\rahul\anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\rahul\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\rahul\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sns.FacetGrid(iris, hue="species", size=5) \
   .map(sns.distplot, "sepal_width") \
   .add_legend();
plt.show();
# Out:
# C:\Users\rahul\anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\rahul\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\rahul\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
counts, bin_edges  = np.histogram(iris_setosa['petal_length'], bins = 10, density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges)
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:], cdf)

counts, bin_edges = np.histogram(iris_setosa['petal_length'],bins = 10, density = True)

pdf = count/(sum(counts))
plt.plot(bin_edges[1:], pdf)

plt.show()
# Out:
# [0.02 0.02 0.04 0.14 0.24 0.28 0.14 0.08 0.   0.04]
# [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]

# %%
#setosa
counts, bin_edges  = np.histogram(iris_setosa['petal_length'], bins = 10, density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges)
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:], cdf)

#virginica
counts, bin_edges  = np.histogram(iris_virginica['petal_length'], bins = 10, density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges)
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:], cdf)

#versicolor
counts, bin_edges  = np.histogram(iris_versicolor['petal_length'], bins = 10, density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges)
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:], cdf)

plt.show()
# Out:
# [0.02 0.02 0.04 0.14 0.24 0.28 0.14 0.08 0.   0.04]
# [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]
# [0.02 0.1  0.24 0.08 0.18 0.16 0.1  0.04 0.02 0.06]
# [4.5  4.74 4.98 5.22 5.46 5.7  5.94 6.18 6.42 6.66 6.9 ]
# [0.02 0.04 0.06 0.04 0.16 0.14 0.12 0.2  0.14 0.08]
# [3.   3.21 3.42 3.63 3.84 4.05 4.26 4.47 4.68 4.89 5.1 ]

# %%
print("Means:")
print(np.mean(iris_setosa['petal_length']))

#Mean with an outlier
#print(np.mean(np.append(iris_setosa['petal_length'], 50)));# here we add outlier 50 to the setosa petal_length,
print(np.mean(iris_virginica['petal_length']))              #mean drastically changed.
print(np.mean(iris_versicolor['petal_length'])) 

print('\nStd-dev:')
print(np.std(iris_setosa['petal_length']))
print(np.std(iris_virginica['petal_length']))
print(np.std(iris_versicolor['petal_length']))
# Out:
# Means:
# 1.464
# 5.552
# 4.26
#
# Std-dev:
# 0.17176728442867115
# 0.5463478745268441
# 0.4651881339845204

# %%
print('\nMedians:')
print(np.median(iris_setosa['petal_length']))
print(np.median(iris_virginica['petal_length']))
print(np.median(iris_versicolor['petal_length']))

print("\nQuantiles:")
print(np.percentile(iris_setosa['petal_length'], np.arange(0,100,25)))
print(np.percentile(iris_virginica['petal_length'], np.arange(0,100,25)))
print(np.percentile(iris_versicolor['petal_length'], np.arange(0,100,25)))


print("\n90th percentiles:")
print(np.percentile(iris_setosa['petal_length'],90))
print(np.percentile(iris_virginica['petal_length'], 90))
print(np.percentile(iris_versicolor['petal_length'], 90))

from statsmodels import robust
print("\nMedian Absolute Deviation")
print(robust.mad(iris_setosa["petal_length"]))
print(robust.mad(iris_virginica["petal_length"]))
print(robust.mad(iris_versicolor["petal_length"]))
# Out:
# Medians:
# 1.5
# 5.55
# 4.35
#
# Quantiles:
# [1.    1.4   1.5   1.575]
# [4.5   5.1   5.55  5.875]
# [3.   4.   4.35 4.6 ]
#
# 90th percentiles:
# 1.7
# 6.31
# 4.8
#
# Median Absolute Deviation
# 0.14826022185056031
# 0.6671709983275211
# 0.5189107764769602

# %%
sns.boxplot(x = 'species', y = 'petal_length', data = iris)
plt.show()

# %%
sns.violinplot(x = "species", y ="petal_length", data = iris, size = 8)
# Out:
# <AxesSubplot: xlabel='species', ylabel='petal_length'>

# %%
sns.jointplot(x = "petal_length", y ="petal_width", data = iris_setosa, kind = "kde")
plt.show()

# %%
# Univariate Analysis - Single Variable- like histogram
#Bi Variate Analysis - 2 variable like petal length & petal width 
#Multivariate Analysis- Taking multiple variable like pair plot.
