# %%
#Seaborn has the capability to take dataframe as the input.

# %%
import pandas as pd
import seaborn as sns
# Out:
# C:\Users\rahul\anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.2)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
car = pd.read_csv('Car_sales.csv')

# %%
car
# Out:
#       Manufacturer          Model  Sales in thousands  4-year resale value  \
# 0       Mitsubishi         3000GT               0.110            20.940000
# 1            Dodge          Viper               0.916            58.470000
# 2    Mercedes-Benz          CL500               0.954            18.072975
# 3       Oldsmobile        Cutlass               1.112            11.240000
# 4          Porsche  Carrera Coupe               1.280            60.625000
# ..             ...            ...                 ...                  ...
# 152          Honda         Accord             230.902            13.210000
# 153           Ford         Taurus             245.815            10.055000
# 154         Toyota          Camry             247.994            13.245000
# 155           Ford       Explorer             276.747            16.640000
# 156           Ford       F-Series             540.561            15.075000
#
# ...

# %%
# I want to know how my fuel efficiency is disributed.

# %%
#IN sns there is aplot called distribution plot.

sns.distplot(car['Fuel efficiency'])
# Out:
# C:\Users\rahul\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot: xlabel='Fuel efficiency', ylabel='Density'>

# %%
car.isnull().sum()
# Out:
# Manufacturer           0
# Model                  0
# Sales in thousands     0
# 4-year resale value    0
# Vehicle type           0
# Price in thousands     2
# Engine size            1
# Horsepower             0
# Wheelbase              1
# Width                  1
# Length                 1
# Curb weight            2
# Fuel capacity          1
# Fuel efficiency        3
# Latest Launch          0
# dtype: int64

# %%
sns.distplot(car['Sales in thousands'], kde = True)
# Here the majority of the value is at the left side. 
# Majority of the values is having low sales values. 
# This type of the chart is Right skewed charts, Outliers are at right side.
#Desity in graph is called probability value.
# Out:
# <AxesSubplot: xlabel='Sales in thousands', ylabel='Density'>

# %%
sns.distplot(car['Sales in thousands'], kde = False) # kde is kernel density estimate
#kde = False gives counts in number.
# Out:
# C:\Users\rahul\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot: xlabel='Sales in thousands'>

# %%
#scatter plots.
#sns we have 2 kinds of plot- 1) Regression(regplot) plot and 2)LM plot Linear Model plot.

sns.regplot(data = car, y ='Fuel efficiency', x = 'Fuel capacity')
# The line is called regression line.
# Out:
# <AxesSubplot: xlabel='Fuel capacity', ylabel='Fuel efficiency'>

# %%
sns.regplot(data = car, y ='Fuel efficiency', x = 'Fuel capacity', fit_reg= False)
# fitreg = False means regression line will  be removed.
# Out:
# <AxesSubplot: xlabel='Fuel capacity', ylabel='Fuel efficiency'>

# %%
sns.lmplot(data = car, y ='Fuel efficiency', x = 'Fuel capacity')

# %%
sns.lmplot(data = car, y ='Fuel efficiency', x = 'Fuel capacity', fit_reg= False)
# Lmplot shown the same plot as regplot, but the difference is that we can differentiate the colour of dots as per the
# vehicle type.

# %%
sns.lmplot(data = car, y ='Fuel efficiency', x = 'Fuel capacity', fit_reg= False, hue= 'Vehicle type')
#hue is not present in the regplot.

# %%
sns.lmplot(data = car, y ='Fuel efficiency', x = 'Fuel capacity', fit_reg= False, col= 'Vehicle type')
#col gives separate graph for both the vehicle type.
#colis not present in regplot

# %%
sns.jointplot(data = car, x = 'Fuel capacity', y = 'Fuel efficiency')

# %%
sns.jointplot(data = car, x = 'Fuel capacity', y = 'Fuel efficiency', kind = 'kde')

# %%
import matplotlib.pyplot as plt

# %%
print(plt.style.available)
plt.style.use('seaborn-v0_8-darkgrid') # We changed the style here of background of graph.
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
#count plot
sns.countplot(data = car, x = 'Vehicle type') # I just want the count. This is only showing the count of records.
# Out:
# <AxesSubplot: xlabel='Vehicle type', ylabel='count'>

# %%
sns.barplot(y = '4-year resale value', x = 'Vehicle type', data = car)
# Out:
# <AxesSubplot: xlabel='Vehicle type', ylabel='4-year resale value'>

# %%
sns.stripplot(y = '4-year resale value', x = 'Vehicle type', data = car)
# Out:
# <AxesSubplot: xlabel='Vehicle type', ylabel='4-year resale value'>

# %%
#Pair plot creates the plot based on numbers.
sns.pairplot(car[['Horsepower', 'Curb weight', 'Fuel capacity', 'Fuel efficiency']])

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\rahul\anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.2)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
car[['Horsepower', 'Curb weight', 'Fuel capacity', 'Fuel efficiency']].corr()
# Out:
#                  Horsepower  Curb weight  Fuel capacity  Fuel efficiency
# Horsepower         1.000000     0.610131       0.499907        -0.611332
# Curb weight        0.610131     1.000000       0.863968        -0.818402
# Fuel capacity      0.499907     0.863968       1.000000        -0.801512
# Fuel efficiency   -0.611332    -0.818402      -0.801512         1.000000

# %%
sns.heatmap(car[['Horsepower', 'Curb weight', 'Fuel capacity', 'Fuel efficiency']].corr(), annot = True)
# Out:
# <AxesSubplot: >

# %%
# Box and whiskers plot-- Very important plot.

sns.boxplot(data = car, x = 'Vehicle type', y = 'Fuel capacity')
# Out:
# <AxesSubplot: xlabel='Vehicle type', ylabel='Fuel capacity'>

# %%
sns.violinplot(data = car, x = 'Vehicle type', y = 'Fuel capacity')
# Out:
# <AxesSubplot: xlabel='Vehicle type', ylabel='Fuel capacity'>
