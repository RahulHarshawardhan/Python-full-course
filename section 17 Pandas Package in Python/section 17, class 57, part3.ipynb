# %%
import pandas as pd

# %%
df = pd.DataFrame({'Country Name': ['USA', 'India', 'Australia', 'Germany', 'Brazil'],
                 'Country Population': [35,135,21,11,21]})

# %%
df
# Out:
#   Country Name  Country Population
# 0          USA                  35
# 1        India                 135
# 2    Australia                  21
# 3      Germany                  11
# 4       Brazil                  21

# %%
df.rename({'country Name': 'Country_Name', 'Country Population': 'Country_Population'}, axis = 'columns')
# Out:
#   Country Name  Country_Population
# 0          USA                  35
# 1        India                 135
# 2    Australia                  21
# 3      Germany                  11
# 4       Brazil                  21

# %%
df.columns = df.columns.str.replace(" ", '_')

# %%
df
# Out:
#   Country_Name  Country_Population
# 0          USA                  35
# 1        India                 135
# 2    Australia                  21
# 3      Germany                  11
# 4       Brazil                  21

# %%
df
# Out:
#   Country_Name  Country_Population
# 0          USA                  35
# 1        India                 135
# 2    Australia                  21
# 3      Germany                  11
# 4       Brazil                  21

# %%
# I want to prefix #

df = df.add_prefix('#')

# %%
#i want to add suffix

df.add_suffix('!')
# Out:
#   #Country_Name!  #Country_Population!
# 0            USA                    35
# 1          India                   135
# 2      Australia                    21
# 3        Germany                    11
# 4         Brazil                    21

# %%
df = pd.DataFrame({'Name': ['Narendra Pratap Singh', 'Arun kumar Mishra', 'Yogendra Nath Reddy'],
             'Location': ['Bhopal, MP', 'Lucknow, UP', 'Kolkatta, WB']})

# %%
df
# Out:
#                     Name      Location
# 0  Narendra Pratap Singh    Bhopal, MP
# 1      Arun kumar Mishra   Lucknow, UP
# 2    Yogendra Nath Reddy  Kolkatta, WB

# %%
# I want to split the name in first name, middle name, last name

name = df.Name.str.split(' ', expand = True)

# %%
name
# Out:
#           0       1       2
# 0  Narendra  Pratap   Singh
# 1      Arun   kumar  Mishra
# 2  Yogendra    Nath   Reddy

# %%
df[['First_Name', 'Middle_Name', 'Last_Name']] =  df.Name.str.split(' ', expand = True)

# %%
df
# Out:
#                     Name      Location First_Name Middle_Name Last_Name
# 0  Narendra Pratap Singh    Bhopal, MP   Narendra      Pratap     Singh
# 1      Arun kumar Mishra   Lucknow, UP       Arun       kumar    Mishra
# 2    Yogendra Nath Reddy  Kolkatta, WB   Yogendra        Nath     Reddy

# %%
df[['City', 'State']] = df.Location.str.split(', ', expand = True)

# %%
df
# Out:
#                     Name      Location First_Name Middle_Name Last_Name  \
# 0  Narendra Pratap Singh    Bhopal, MP   Narendra      Pratap     Singh
# 1      Arun kumar Mishra   Lucknow, UP       Arun       kumar    Mishra
# 2    Yogendra Nath Reddy  Kolkatta, WB   Yogendra        Nath     Reddy
#
#        City State
# 0    Bhopal    MP
# 1   Lucknow    UP
# 2  Kolkatta    WB

# %%
 df.Location.str.split(', ', expand = True)
# Out:
#           0   1
# 0    Bhopal  MP
# 1   Lucknow  UP
# 2  Kolkatta  WB

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'city': ['Delhi','Nagpur','Mumbai'],
             'Max_Min_Temp': [[34,23],[43,32],[32,21]]})

# %%
df
# Out:
#      city Max_Min_Temp
# 0   Delhi     [34, 23]
# 1  Nagpur     [43, 32]
# 2  Mumbai     [32, 21]

# %%
pd.concat([df,df.Max_Min_Temp.apply(pd.Series)], axis = 'columns')
# Out:
#      city Max_Min_Temp   0   1
# 0   Delhi     [34, 23]  34  23
# 1  Nagpur     [43, 32]  43  32
# 2  Mumbai     [32, 21]  32  21

# %%
df[['city','Max_Min_Temp','Max_Temp','Min_Temp']] = pd.concat([df,df.Max_Min_Temp.apply(pd.Series)], axis = 'columns')

# %%
df
# Out:
#      city Max_Min_Temp  Max_Temp  Min_Temp
# 0   Delhi     [34, 23]        34        23
# 1  Nagpur     [43, 32]        43        32
# 2  Mumbai     [32, 21]        32        21

# %%
type(df.city) #city is a series.
# Out:
# pandas.core.series.Series

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\rahul\\Rahul Tiwari 30\\section 17 Pandas Package in Python'

# %%
tips = pd.read_csv('tips.csv')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# I want to reverse my order. from index 244 to 0.

tips.iloc[::-1]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 243       18.78  3.00  Female     No  Thur  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# ..          ...   ...     ...    ...   ...     ...   ...
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 0         16.99  1.01  Female     No   Sun  Dinner     2
#
# [244 rows x 7 columns]

# %%
#resetting the index number as 244--> 0.
tips.iloc[::-1].reset_index(drop = True)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         18.78  3.00  Female     No  Thur  Dinner     2
# 1         17.82  1.75    Male     No   Sat  Dinner     2
# 2         22.67  2.00    Male    Yes   Sat  Dinner     2
# 3         27.18  2.00  Female    Yes   Sat  Dinner     2
# 4         29.03  5.92    Male     No   Sat  Dinner     3
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       24.59  3.61  Female     No   Sun  Dinner     4
# 240       23.68  3.31    Male     No   Sun  Dinner     2
# 241       21.01  3.50    Male     No   Sun  Dinner     3
# 242       10.34  1.66    Male     No   Sun  Dinner     3
# 243       16.99  1.01  Female     No   Sun  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# reversed the column output
tips.iloc[:,::-1]
# Out:
#      size    time   day smoker     sex   tip  total_bill
# 0       2  Dinner   Sun     No  Female  1.01       16.99
# 1       3  Dinner   Sun     No    Male  1.66       10.34
# 2       3  Dinner   Sun     No    Male  3.50       21.01
# 3       2  Dinner   Sun     No    Male  3.31       23.68
# 4       4  Dinner   Sun     No  Female  3.61       24.59
# ..    ...     ...   ...    ...     ...   ...         ...
# 239     3  Dinner   Sat     No    Male  5.92       29.03
# 240     2  Dinner   Sat    Yes  Female  2.00       27.18
# 241     2  Dinner   Sat    Yes    Male  2.00       22.67
# 242     2  Dinner   Sat     No    Male  1.75       17.82
# 243     2  Dinner  Thur     No  Female  3.00       18.78
#
# [244 rows x 7 columns]

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
#Interested in float column
tips.select_dtypes(include = 'float64')
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
tips.select_dtypes(include = 'object')
# Out:
#         sex smoker   day    time
# 0    Female     No   Sun  Dinner
# 1      Male     No   Sun  Dinner
# 2      Male     No   Sun  Dinner
# 3      Male     No   Sun  Dinner
# 4    Female     No   Sun  Dinner
# ..      ...    ...   ...     ...
# 239    Male     No   Sat  Dinner
# 240  Female    Yes   Sat  Dinner
# 241    Male    Yes   Sat  Dinner
# 242    Male     No   Sat  Dinner
# 243  Female     No  Thur  Dinner
#
# [244 rows x 4 columns]

# %%
tips.select_dtypes(include = 'int64')
# Out:
#      size
# 0       2
# 1       3
# 2       3
# 3       2
# 4       4
# ..    ...
# 239     3
# 240     2
# 241     2
# 242     2
# 243     2
#
# [244 rows x 1 columns]

# %%
tips.select_dtypes(exclude = 'int64')
# Out:
#      total_bill   tip     sex smoker   day    time
# 0         16.99  1.01  Female     No   Sun  Dinner
# 1         10.34  1.66    Male     No   Sun  Dinner
# 2         21.01  3.50    Male     No   Sun  Dinner
# 3         23.68  3.31    Male     No   Sun  Dinner
# 4         24.59  3.61  Female     No   Sun  Dinner
# ..          ...   ...     ...    ...   ...     ...
# 239       29.03  5.92    Male     No   Sat  Dinner
# 240       27.18  2.00  Female    Yes   Sat  Dinner
# 241       22.67  2.00    Male    Yes   Sat  Dinner
# 242       17.82  1.75    Male     No   Sat  Dinner
# 243       18.78  3.00  Female     No  Thur  Dinner
#
# [244 rows x 6 columns]

# %%
tips.select_dtypes(exclude = ['int64', 'object'])
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# I want to sum up the total bill by gender

tips.groupby('sex').agg({'total_bill': np.sum})
# Out:
#         total_bill
# sex
# Female     1570.95
# Male       3256.82

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#I want prcentage wise of total bill gender wise

totalsales = tips.groupby('sex').total_bill.transform('sum')

# %%
totalsales
# Out:
# 0      1570.95
# 1      3256.82
# 2      3256.82
# 3      3256.82
# 4      1570.95
#         ...
# 239    3256.82
# 240    1570.95
# 241    3256.82
# 242    3256.82
# 243    1570.95
# Name: total_bill, Length: 244, dtype: float64

# %%
tips['TotalSales'] = totalsales

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  TotalSales
# 0         16.99  1.01  Female     No   Sun  Dinner     2     1570.95
# 1         10.34  1.66    Male     No   Sun  Dinner     3     3256.82
# 2         21.01  3.50    Male     No   Sun  Dinner     3     3256.82
# 3         23.68  3.31    Male     No   Sun  Dinner     2     3256.82
# 4         24.59  3.61  Female     No   Sun  Dinner     4     1570.95
# ..          ...   ...     ...    ...   ...     ...   ...         ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3     3256.82
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2     1570.95
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2     3256.82
# 242       17.82  1.75    Male     No   Sat  Dinner     2     3256.82
# 243       18.78  3.00  Female     No  Thur  Dinner     2     1570.95
#
# [244 rows x 8 columns]

# %%
tips['percent_of_total'] = (tips.total_bill/tips.TotalSales)*100

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  TotalSales  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2     1570.95
# 1         10.34  1.66    Male     No   Sun  Dinner     3     3256.82
# 2         21.01  3.50    Male     No   Sun  Dinner     3     3256.82
# 3         23.68  3.31    Male     No   Sun  Dinner     2     3256.82
# 4         24.59  3.61  Female     No   Sun  Dinner     4     1570.95
# ..          ...   ...     ...    ...   ...     ...   ...         ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3     3256.82
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2     1570.95
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2     3256.82
# 242       17.82  1.75    Male     No   Sat  Dinner     2     3256.82
# 243       18.78  3.00  Female     No  Thur  Dinner     2     1570.95
#
#      percent_of_total
# 0            1.081511
# 1            0.317488
# 2            0.645108
# 3            0.727090
# ...

# %%
tips.describe()
# Out:
#        total_bill         tip        size   TotalSales  percent_of_total
# count  244.000000  244.000000  244.000000   244.000000        244.000000
# mean    19.785943    2.998279    2.569672  2655.710615          0.819672
# std      8.902412    1.383638    0.951100   809.162011          0.451931
# min      3.070000    1.000000    1.000000  1570.950000          0.195423
# 25%     13.347500    2.000000    2.000000  1570.950000          0.500642
# 50%     17.795000    2.900000    2.000000  3256.820000          0.710158
# 75%     24.127500    3.562500    3.000000  3256.820000          1.032815
# max     50.810000   10.000000    6.000000  3256.820000          2.819950

# %%
#loc takes row name and columnn name: 
# Loc requires row name as well.
tips.describe().loc['min': 'max', 'total_bill':'size']#In loc it takes the last value.
# Out:
#      total_bill      tip  size
# min      3.0700   1.0000   1.0
# 25%     13.3475   2.0000   2.0
# 50%     17.7950   2.9000   2.0
# 75%     24.1275   3.5625   3.0
# max     50.8100  10.0000   6.0

# %%
tips.describe().loc[:, 'total_bill':'size']
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.groupby(['sex', 'day']).total_bill.mean().unstack()
# Out:
# day           Fri        Sat        Sun       Thur
# sex
# Female  14.145556  19.680357  19.872222  16.715312
# Male    19.857000  20.802542  21.887241  18.714667

# %%
tips.pivot_table(index = 'sex', columns = 'day', values = 'total_bill', aggfunc = 'mean')
# Out:
# day           Fri        Sat        Sun       Thur
# sex
# Female  14.145556  19.680357  19.872222  16.715312
# Male    19.857000  20.802542  21.887241  18.714667

# %%
# I have multiple csv file and want to have a single dataframe

from glob import glob

# %%
sample = sorted(glob('tips*.csv'))

# %%
sample
# Out:
# ['tips1.csv', 'tips2.csv', 'tips3.csv', 'tips4.csv']

# %%
pd.concat(pd.read_csv(file) for file in sample)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2
# 0       17.92  4.08    Male     No  Sat  Dinner     2
# 1       20.29  2.75  Female     No  Sat  Dinner     2
# 2       15.77  2.23  Female     No  Sat  Dinner     2
# 3       39.42  7.58    Male     No  Sat  Dinner     4
# 4       19.82  3.18    Male     No  Sat  Dinner     2
# 5       17.81  2.34    Male     No  Sat  Dinner     4
# ...

# %%
pd.concat((pd.read_csv(file) for file in sample), ignore_index = True)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 1        10.34  1.66    Male     No  Sun  Dinner     3
# 2        21.01  3.50    Male     No  Sun  Dinner     3
# 3        23.68  3.31    Male     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 5        25.29  4.71    Male     No  Sun  Dinner     4
# 6         8.77  2.00    Male     No  Sun  Dinner     2
# 7        26.88  3.12    Male     No  Sun  Dinner     4
# 8        15.04  1.96    Male     No  Sun  Dinner     2
# 9        14.78  3.23    Male     No  Sun  Dinner     2
# 10       17.92  4.08    Male     No  Sat  Dinner     2
# 11       20.29  2.75  Female     No  Sat  Dinner     2
# 12       15.77  2.23  Female     No  Sat  Dinner     2
# 13       39.42  7.58    Male     No  Sat  Dinner     4
# 14       19.82  3.18    Male     No  Sat  Dinner     2
# 15       17.81  2.34    Male     No  Sat  Dinner     4
# ...

# %%
pd.read_clipboard()
# Out:
#    total_bill   tip     sex
# 0       16.31  2.00    Male
# 1       16.93  3.07  Female
# 2       18.69  2.31    Male
# 3       31.27  5.00    Male
# 4       16.04  2.24    Male
# 5       17.46  2.54    Male

# %%
pd.read_clipboard()
# Out:
#    16.31     2    Male
# 0  16.93  3.07  Female
# 1  18.69  2.31    Male
# 2  31.27  5.00    Male
# 3  16.04  2.24    Male
# 4  17.46  2.54    Male
# 5  13.94  3.06    Male
# 6   9.68  1.32    Male
# 7  30.40  5.60    Male

# %%
a =pd.read_clipboard(sep = ',', names = ['total_bill', 'tip', 'sex'])

# %%
a
# Out:
#    total_bill   tip     sex
# 0       16.31  2.00    Male
# 1       16.93  3.07  Female
# 2       18.69  2.31    Male
# 3       31.27  5.00    Male
# 4       16.04  2.24    Male
# 5       17.46  2.54    Male
# 6       13.94  3.06    Male
# 7        9.68  1.32    Male
# 8       30.40  5.60    Male

# %%
# I want to export to my local machine this dataframe.
a.to_csv('a.csv')

# %%
pd.read_csv('a.csv') # Here we read file from the local machine but we have another column of index. We dont want that.
#
# Out:
#    Unnamed: 0  total_bill   tip     sex
# 0           0       16.31  2.00    Male
# 1           1       16.93  3.07  Female
# 2           2       18.69  2.31    Male
# 3           3       31.27  5.00    Male
# 4           4       16.04  2.24    Male
# 5           5       17.46  2.54    Male
# 6           6       13.94  3.06    Male
# 7           7        9.68  1.32    Male
# 8           8       30.40  5.60    Male

# %%
pd.read_csv('a.csv', index_col = 0)
# Out:
#    total_bill   tip     sex
# 0       16.31  2.00    Male
# 1       16.93  3.07  Female
# 2       18.69  2.31    Male
# 3       31.27  5.00    Male
# 4       16.04  2.24    Male
# 5       17.46  2.54    Male
# 6       13.94  3.06    Male
# 7        9.68  1.32    Male
# 8       30.40  5.60    Male

# %%
df = pd.DataFrame({'Order_id': ['CA-1234-65454', 'CA-2015-54332', 'US-2020=43344', 'US-5434-555654'],
             'Furniture': [43.54,65.67,76.45,66.78],
             'Office Supplies': [54.66, 76.66, 43.44, 67.88],
             'Technology': [54.66, 34.44,33.54, 66.55]})

# %%
df
# Out:
#          Order_id  Furniture  Office Supplies  Technology
# 0   CA-1234-65454      43.54            54.66       54.66
# 1   CA-2015-54332      65.67            76.66       34.44
# 2   US-2020=43344      76.45            43.44       33.54
# 3  US-5434-555654      66.78            67.88       66.55

# %%
df = df.melt(id_vars= 'Order_id', var_name= 'Category', value_name= 'Sales')

# %%
df
# Out:
#           Order_id         Category  Sales
# 0    CA-1234-65454        Furniture  43.54
# 1    CA-2015-54332        Furniture  65.67
# 2    US-2020=43344        Furniture  76.45
# 3   US-5434-555654        Furniture  66.78
# 4    CA-1234-65454  Office Supplies  54.66
# 5    CA-2015-54332  Office Supplies  76.66
# 6    US-2020=43344  Office Supplies  43.44
# 7   US-5434-555654  Office Supplies  67.88
# 8    CA-1234-65454       Technology  54.66
# 9    CA-2015-54332       Technology  34.44
# 10   US-2020=43344       Technology  33.54
# 11  US-5434-555654       Technology  66.55

# %%
df = pd.DataFrame({'Year': [2019, 2020, 2019, 2020], 'Day Of Year':[350,365,1,120]})

# %%
df
# Out:
#    Year  Day Of Year
# 0  2019          350
# 1  2020          365
# 2  2019            1
# 3  2020          120

# %%
df['combined'] = df['Year']*1000 +df['Day Of Year']

# %%
df
# Out:
#    Year  Day Of Year  combined
# 0  2019          350   2019350
# 1  2020          365   2020365
# 2  2019            1   2019001
# 3  2020          120   2020120

# %%
df['Date'] = pd.to_datetime(df['combined'], format= '%Y%j' )

# %%
df
# Out:
#    Year  Day Of Year  combined       Date
# 0  2019          350   2019350 2019-12-16
# 1  2020          365   2020365 2020-12-30
# 2  2019            1   2019001 2019-01-01
# 3  2020          120   2020120 2020-04-29

# %%
df =pd.DataFrame({'Order_id': ['CA-1232', 'CA-4332', 'CA-5433', 'CA-5432'],
             'Category': ['Furniture', 'Office Supplies', 'Technology', 'Furtniture'],
             'Sales': [456, 767,666,355]})

# %%
df.insert(2, 'Discount', df['Sales']*0.1)

# %%
df
# Out:
#   Order_id         Category  Discount  Sales
# 0  CA-1232        Furniture      45.6    456
# 1  CA-4332  Office Supplies      76.7    767
# 2  CA-5433       Technology      66.6    666
# 3  CA-5432       Furtniture      35.5    355

# %%
df
# Out:
#   Order_id         Category  Discount  Sales
# 0  CA-1232        Furniture      45.6    456
# 1  CA-4332  Office Supplies      76.7    767
# 2  CA-5433       Technology      66.6    666
# 3  CA-5432       Furtniture      35.5    355

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  TotalSales  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2     1570.95
# 1         10.34  1.66    Male     No   Sun  Dinner     3     3256.82
# 2         21.01  3.50    Male     No   Sun  Dinner     3     3256.82
# 3         23.68  3.31    Male     No   Sun  Dinner     2     3256.82
# 4         24.59  3.61  Female     No   Sun  Dinner     4     1570.95
# ..          ...   ...     ...    ...   ...     ...   ...         ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3     3256.82
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2     1570.95
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2     3256.82
# 242       17.82  1.75    Male     No   Sat  Dinner     2     3256.82
# 243       18.78  3.00  Female     No  Thur  Dinner     2     1570.95
#
#      percent_of_total
# 0            1.081511
# 1            0.317488
# 2            0.645108
# 3            0.727090
# ...

# %%
pd.set_option('max_rows', None) # To show full rows. If we want to restrict the number of rows then put number 
#inplace of None.
pd.set_option('display.max_columns', None )# To restrict the number of columns. None means full number of columns. If
# want to restrict put number inpplace of None.

# %%
tips
# Out:
#      total_bill    tip     sex smoker   day    time  size  TotalSales  \
# 0         16.99   1.01  Female     No   Sun  Dinner     2     1570.95
# 1         10.34   1.66    Male     No   Sun  Dinner     3     3256.82
# 2         21.01   3.50    Male     No   Sun  Dinner     3     3256.82
# 3         23.68   3.31    Male     No   Sun  Dinner     2     3256.82
# 4         24.59   3.61  Female     No   Sun  Dinner     4     1570.95
# 5         25.29   4.71    Male     No   Sun  Dinner     4     3256.82
# 6          8.77   2.00    Male     No   Sun  Dinner     2     3256.82
# 7         26.88   3.12    Male     No   Sun  Dinner     4     3256.82
# 8         15.04   1.96    Male     No   Sun  Dinner     2     3256.82
# 9         14.78   3.23    Male     No   Sun  Dinner     2     3256.82
# 10        10.27   1.71    Male     No   Sun  Dinner     2     3256.82
# 11        35.26   5.00  Female     No   Sun  Dinner     4     1570.95
# ...
